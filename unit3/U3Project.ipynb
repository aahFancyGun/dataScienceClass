# %%
# !pip install "preliz[full,notebook]"

# %%
import preliz as pz
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import arviz as az
import pymc as pm
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
url = "https://raw.githubusercontent.com/aahFancyGun/dataScienceClass/blob/master/unit3/FL_Dashboard_AY2009_2010_Q1.csv"

data_loans = pd.read_csv(url)

print(data_loans)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 url = "https://raw.githubusercontent.com/aahFancyGun/dataScienceClass/blob/master/unit3/FL_Dashboard_AY2009_2010_Q1.csv"
# ----> 3 data_loans = pd.read_csv(url)
#       5 print(data_loans)
#
# ...
